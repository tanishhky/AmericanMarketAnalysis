# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os
from concurrent.futures import ThreadPoolExecutor, as_completed
import yfinance as yf
import time

# %%
WIKI_URL = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

def scrape_wikipedia_sp500():
    """Scrape S&P 500 companies and their sectors from Wikipedia."""
    response = requests.get(WIKI_URL)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    table = soup.find('table', {'id': 'constituents'})
    rows = table.find_all('tr')[1:]  # Skip header row
    
    companies_data = []
    for row in rows:
        cols = row.find_all('td')
        ticker = cols[0].text.strip()
        company_name = cols[1].text.strip()
        sector = cols[3].text.strip()
        companies_data.append((ticker, company_name, sector))
    
    return companies_data

# %%
def get_sp500_sectors(companies_data):
    """Return a list of unique sectors."""
    return list(set(company[2] for company in companies_data))

def get_sector_companies(sector, companies_data):
    """Return the list of companies belonging to a sector."""
    return [company[0] for company in companies_data if company[2] == sector]

def download_market_cap_data(ticker, start_date, end_date):
    """Download the stock's market capitalization at the quarter end."""
    try:
        stock = yf.Ticker(ticker)
        df = stock.history(start=start_date, end=end_date)
        if df.empty:
            print(f"No data found for {ticker}")
            return None

        # Calculate Market Cap = Close Price * Shares Outstanding
        shares_outstanding = stock.info.get('sharesOutstanding', None)
        if shares_outstanding is None:
            print(f"No shares outstanding data for {ticker}")
            return None
        
        df['MarketCap'] = df['Close'] * shares_outstanding
        df = df[['MarketCap']]  # Only keep MarketCap column
        
        # Resample to get the last value at the end of each quarter
        df = df.resample('QE').last()
        df['Ticker'] = ticker  # Add ticker as a column
        return df
    except Exception as e:
        print(f"Error downloading data for {ticker}: {str(e)}")
        return None

def process_sector(sector, start_date, end_date, companies_data):
    """Process each sector and calculate the market cap at quarter end."""
    companies = get_sector_companies(sector, companies_data)
    if len(companies) < 3:
        print(f"Skipping {sector} sector: Only {len(companies)} companies found.")
        return None

    print(f"Processing {sector} sector ({len(companies)} companies)...")
    print(companies)
    results = []

    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_ticker = {executor.submit(download_market_cap_data, ticker, start_date, end_date): ticker for ticker in companies}
        for future in as_completed(future_to_ticker):
            ticker, result = future_to_ticker[future], future.result()
            if result is not None and not result.empty:
                results.append(result)
            time.sleep(1)  # To avoid overwhelming the Yahoo Finance API

    if not results:
        print(f"No valid results for {sector} sector.")
        return None

    try:
        # Combine the results into a single DataFrame
        combined_results = pd.concat(results)
        combined_results.reset_index(inplace=True)  # Reset index to get Date as a column
        combined_results.rename(columns={'index': 'Date'}, inplace=True)  # Rename the index column to Date
        return combined_results
    except ValueError as e:
        print(f"Error combining results for {sector} sector: {str(e)}")
        return None

def main():
    # Set the date range from Q1 2015 to Q2 2024 (or current date if earlier)
    start_date = pd.Timestamp('2019-09-01')
    end_date = pd.Timestamp('2024-09-30')
    end_date = min(end_date, pd.Timestamp.now())

    # Scrape Wikipedia for S&P 500 companies and sectors
    companies_data = scrape_wikipedia_sp500()

    # Get all unique sectors
    sectors = get_sp500_sectors(companies_data)

    # Create a directory for output files
    output_dir = "sector_mkt_cap_results"
    os.makedirs(output_dir, exist_ok=True)

    # Process each sector
    for sector in sectors:
        sector_results = process_sector(sector, start_date, end_date, companies_data)
        if sector_results is not None:
            # Save results to CSV
            csv_filename = os.path.join(output_dir, f"{sector}_mkt_cap_quarter_end.csv")
            sector_results.to_csv(csv_filename, index=False)  # Save without index
            print(f"Results saved to {csv_filename}")

            # Display summary
            print(f"Summary for {sector} sector:")
            print(sector_results.head())
            print("\n" + "="*50 + "\n")
        else:
            print(f"No results to save for {sector} sector.")
            print("\n" + "="*50 + "\n")

    print("All sectors processed.")

if __name__ == "__main__":
    main()
# Out:
# Skipping Gold sector: Only 1 companies found.
# No results to save for Gold sector.
#
# ==================================================
#
# Processing Paper & Plastic Packaging Products & Materials sector (5 companies)...
# ['AMCR', 'AVY', 'IP', 'PKG', 'SW']
# Results saved to sector_mkt_cap_results/Paper & Plastic Packaging Products & Materials_mkt_cap_quarter_end.csv
# Summary for Paper & Plastic Packaging Products & Materials sector:
#                        Date     MarketCap Ticker
# 0 2024-09-30 00:00:00-04:00  2.605461e+10     SW
# 1 2019-09-30 00:00:00-04:00  1.129108e+10   AMCR
# 2 2019-12-31 00:00:00-05:00  1.269780e+10   AMCR
# 3 2020-03-31 00:00:00-04:00  9.624698e+09   AMCR
# 4 2020-06-30 00:00:00-04:00  1.224279e+10   AMCR
#
# ==================================================
#
# Processing Health Care Supplies sector (3 companies)...
# ['ALGN', 'COO', 'WST']
# Results saved to sector_mkt_cap_results/Health Care Supplies_mkt_cap_quarter_end.csv
# Summary for Health Care Supplies sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.350624e+10   ALGN
# 1 2019-12-31 00:00:00-05:00  2.083120e+10   ALGN
# 2 2020-03-31 00:00:00-04:00  1.298591e+10   ALGN
# 3 2020-06-30 00:00:00-04:00  2.048780e+10   ALGN
# 4 2020-09-30 00:00:00-04:00  2.443844e+10   ALGN
#
# ==================================================
#
# Skipping Technology Distributors sector: Only 1 companies found.
# No results to save for Technology Distributors sector.
#
# ==================================================
#
# Processing Electronic Equipment & Instruments sector (5 companies)...
# ['KEYS', 'ROP', 'TDY', 'TRMB', 'ZBRA']
# Results saved to sector_mkt_cap_results/Electronic Equipment & Instruments_mkt_cap_quarter_end.csv
# Summary for Electronic Equipment & Instruments sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  9.477713e+09   TRMB
# 1 2019-12-31 00:00:00-05:00  1.018103e+10   TRMB
# 2 2020-03-31 00:00:00-04:00  7.773141e+09   TRMB
# 3 2020-06-30 00:00:00-04:00  1.054734e+10   TRMB
# 4 2020-09-30 00:00:00-04:00  1.189293e+10   TRMB
#
# ==================================================
#
# Skipping Industrial Conglomerates sector: Only 2 companies found.
# No results to save for Industrial Conglomerates sector.
#
# ==================================================
#
# Processing Integrated Oil & Gas sector (3 companies)...
# ['CVX', 'XOM', 'HES']
# Results saved to sector_mkt_cap_results/Integrated Oil & Gas_mkt_cap_quarter_end.csv
# Summary for Integrated Oil & Gas sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.729165e+10    HES
# 1 2019-12-31 00:00:00-05:00  1.917708e+10    HES
# 2 2020-03-31 00:00:00-04:00  9.631722e+09    HES
# 3 2020-06-30 00:00:00-04:00  1.506310e+10    HES
# 4 2020-09-30 00:00:00-04:00  1.196907e+10    HES
#
# ==================================================
#
# Skipping Industrial Gases sector: Only 2 companies found.
# No results to save for Industrial Gases sector.
#
# ==================================================
#
# Skipping Data Center REITs sector: Only 2 companies found.
# No results to save for Data Center REITs sector.
#
# ==================================================
#
# Processing Automobile Manufacturers sector (3 companies)...
# ['F', 'GM', 'TSLA']
# Results saved to sector_mkt_cap_results/Automobile Manufacturers_mkt_cap_quarter_end.csv
# Summary for Automobile Manufacturers sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  3.935838e+10     GM
# 1 2019-12-31 00:00:00-05:00  3.884661e+10     GM
# 2 2020-03-31 00:00:00-04:00  2.232459e+10     GM
# 3 2020-06-30 00:00:00-04:00  2.718056e+10     GM
# 4 2020-09-30 00:00:00-04:00  3.178944e+10     GM
#
# ==================================================
#
# Processing Systems Software sector (6 companies)...
# ['CRWD', 'FTNT', 'GEN', 'MSFT', 'PANW', 'NOW']
# Results saved to sector_mkt_cap_results/Systems Software_mkt_cap_quarter_end.csv
# Summary for Systems Software sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.356973e+10   CRWD
# 1 2019-12-31 00:00:00-05:00  1.160560e+10   CRWD
# 2 2020-03-31 00:00:00-04:00  1.295768e+10   CRWD
# 3 2020-06-30 00:00:00-04:00  2.333919e+10   CRWD
# 4 2020-09-30 00:00:00-04:00  3.195670e+10   CRWD
#
# ==================================================
#
# Skipping Electronic Manufacturing Services sector: Only 2 companies found.
# No results to save for Electronic Manufacturing Services sector.
#
# ==================================================
#
# Processing Health Care Distributors sector (4 companies)...
# ['CAH', 'COR', 'HSIC', 'MCK']
# Results saved to sector_mkt_cap_results/Health Care Distributors_mkt_cap_quarter_end.csv
# Summary for Health Care Distributors sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.917244e+09   HSIC
# 1 2019-12-31 00:00:00-05:00  8.318716e+09   HSIC
# 2 2020-03-31 00:00:00-04:00  6.298884e+09   HSIC
# 3 2020-06-30 00:00:00-04:00  7.280124e+09   HSIC
# 4 2020-09-30 00:00:00-04:00  7.328749e+09   HSIC
#
# ==================================================
#
# Processing Semiconductor Materials & Equipment sector (5 companies)...
# ['AMAT', 'ENPH', 'KLAC', 'LRCX', 'TER']
# Results saved to sector_mkt_cap_results/Semiconductor Materials & Equipment_mkt_cap_quarter_end.csv
# Summary for Semiconductor Materials & Equipment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  3.003429e+09   ENPH
# 1 2019-12-31 00:00:00-05:00  3.530346e+09   ENPH
# 2 2020-03-31 00:00:00-04:00  4.362605e+09   ENPH
# 3 2020-06-30 00:00:00-04:00  6.427040e+09   ENPH
# 4 2020-09-30 00:00:00-04:00  1.115849e+10   ENPH
#
# ==================================================
#
# Skipping Health Care Technology sector: Only 1 companies found.
# No results to save for Health Care Technology sector.
#
# ==================================================
#
# Processing Insurance Brokers sector (6 companies)...
# ['AON', 'AJG', 'BRO', 'ERIE', 'MMC', 'WTW']
# Results saved to sector_mkt_cap_results/Insurance Brokers_mkt_cap_quarter_end.csv
# Summary for Insurance Brokers sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.685231e+09   ERIE
# 1 2019-12-31 00:00:00-05:00  6.906319e+09   ERIE
# 2 2020-03-31 00:00:00-04:00  6.203283e+09   ERIE
# 3 2020-06-30 00:00:00-04:00  8.078582e+09   ERIE
# 4 2020-09-30 00:00:00-04:00  8.897477e+09   ERIE
#
# ==================================================
#
# Processing Multi-Family Residential REITs sector (6 companies)...
# ['AVB', 'CPT', 'EQR', 'ESS', 'MAA', 'UDR']
# Results saved to sector_mkt_cap_results/Multi-Family Residential REITs_mkt_cap_quarter_end.csv
# Summary for Multi-Family Residential REITs sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.764157e+10    ESS
# 1 2019-12-31 00:00:00-05:00  1.635513e+10    ESS
# 2 2020-03-31 00:00:00-04:00  1.208235e+10    ESS
# 3 2020-06-30 00:00:00-04:00  1.268956e+10    ESS
# 4 2020-09-30 00:00:00-04:00  1.123056e+10    ESS
#
# ==================================================
#
# Processing Life Sciences Tools & Services sector (8 companies)...
# ['A', 'TECH', 'CRL', 'DHR', 'IQV', 'MTD', 'TMO', 'WAT']
# Results saved to sector_mkt_cap_results/Life Sciences Tools & Services_mkt_cap_quarter_end.csv
# Summary for Life Sciences Tools & Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  6.768899e+09    CRL
# 1 2019-12-31 00:00:00-05:00  7.811566e+09    CRL
# 2 2020-03-31 00:00:00-04:00  6.453900e+09    CRL
# 3 2020-06-30 00:00:00-04:00  8.915597e+09    CRL
# 4 2020-09-30 00:00:00-04:00  1.157979e+10    CRL
#
# ==================================================
#
# Skipping Cable & Satellite sector: Only 2 companies found.
# No results to save for Cable & Satellite sector.
#
# ==================================================
#
# Skipping Real Estate Services sector: Only 2 companies found.
# No results to save for Real Estate Services sector.
#
# ==================================================
#
# Processing Human Resource & Employment Services sector (4 companies)...
# ['ADP', 'DAY', 'PAYX', 'PAYC']
# Results saved to sector_mkt_cap_results/Human Resource & Employment Services_mkt_cap_quarter_end.csv
# Summary for Human Resource & Employment Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.785649e+09    DAY
# 1 2019-12-31 00:00:00-05:00  1.070468e+10    DAY
# 2 2020-03-31 00:00:00-04:00  7.896039e+09    DAY
# 3 2020-06-30 00:00:00-04:00  1.250088e+10    DAY
# 4 2020-09-30 00:00:00-04:00  1.303391e+10    DAY
#
# ==================================================
#
# Skipping Heavy Electrical Equipment sector: Only 1 companies found.
# No results to save for Heavy Electrical Equipment sector.
#
# ==================================================
#
# Processing Transaction & Payment Processing Services sector (8 companies)...
# ['CPAY', 'FIS', 'FI', 'GPN', 'JKHY', 'MA', 'PYPL', 'V']
# Results saved to sector_mkt_cap_results/Transaction & Payment Processing Services_mkt_cap_quarter_end.csv
# Summary for Transaction & Payment Processing Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  5.893431e+10     FI
# 1 2019-12-31 00:00:00-05:00  6.578410e+10     FI
# 2 2020-03-31 00:00:00-04:00  5.404161e+10     FI
# 3 2020-06-30 00:00:00-04:00  5.553787e+10     FI
# 4 2020-09-30 00:00:00-04:00  5.862710e+10     FI
#
# ==================================================
#
# Skipping Office REITs sector: Only 2 companies found.
# No results to save for Office REITs sector.
#
# ==================================================
#
# Processing Personal Care Products sector (3 companies)...
# ['EL', 'KVUE', 'PG']
# Results saved to sector_mkt_cap_results/Personal Care Products_mkt_cap_quarter_end.csv
# Summary for Personal Care Products sector:
#                        Date     MarketCap Ticker
# 0 2023-06-30 00:00:00-04:00  4.779790e+10   KVUE
# 1 2023-09-30 00:00:00-04:00  3.663756e+10   KVUE
# 2 2023-12-31 00:00:00-05:00  3.969346e+10   KVUE
# 3 2024-03-31 00:00:00-04:00  3.997250e+10   KVUE
# 4 2024-06-30 00:00:00-04:00  3.422172e+10   KVUE
#
# ==================================================
#
# Skipping Wireless Telecommunication Services sector: Only 1 companies found.
# No results to save for Wireless Telecommunication Services sector.
#
# ==================================================
#
# Skipping Self-Storage REITs sector: Only 2 companies found.
# No results to save for Self-Storage REITs sector.
#
# ==================================================
#
# Processing Building Products sector (7 companies)...
# ['AOS', 'ALLE', 'BLDR', 'CARR', 'JCI', 'MAS', 'TT']
# Results saved to sector_mkt_cap_results/Building Products_mkt_cap_quarter_end.csv
# Summary for Building Products sector:
#                        Date     MarketCap Ticker
# 0 2020-03-31 00:00:00-04:00  1.456790e+10   CARR
# 1 2020-06-30 00:00:00-04:00  1.883419e+10   CARR
# 2 2020-09-30 00:00:00-04:00  2.588642e+10   CARR
# 3 2020-12-31 00:00:00-05:00  3.214951e+10   CARR
# 4 2021-03-31 00:00:00-04:00  3.598496e+10   CARR
#
# ==================================================
#
# Processing Environmental & Facilities Services sector (4 companies)...
# ['RSG', 'ROL', 'VLTO', 'WM']
# Results saved to sector_mkt_cap_results/Environmental & Facilities Services_mkt_cap_quarter_end.csv
# Summary for Environmental & Facilities Services sector:
#                        Date     MarketCap Ticker
# 0 2023-12-31 00:00:00-05:00  2.028789e+10   VLTO
# 1 2024-03-31 00:00:00-04:00  2.188839e+10   VLTO
# 2 2024-06-30 00:00:00-04:00  2.359140e+10   VLTO
# 3 2024-09-30 00:00:00-04:00  2.727807e+10   VLTO
# 4 2019-09-30 00:00:00-04:00  4.243505e+10     WM
#
# ==================================================
#
# Processing Casinos & Gaming sector (4 companies)...
# ['CZR', 'LVS', 'MGM', 'WYNN']
# Results saved to sector_mkt_cap_results/Casinos & Gaming_mkt_cap_quarter_end.csv
# Summary for Casinos & Gaming sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.155476e+10   WYNN
# 1 2019-12-31 00:00:00-05:00  1.488236e+10   WYNN
# 2 2020-03-31 00:00:00-04:00  6.504545e+09   WYNN
# 3 2020-06-30 00:00:00-04:00  8.049901e+09   WYNN
# 4 2020-09-30 00:00:00-04:00  7.760282e+09   WYNN
#
# ==================================================
#
# Processing Passenger Airlines sector (3 companies)...
# ['DAL', 'LUV', 'UAL']
# Results saved to sector_mkt_cap_results/Passenger Airlines_mkt_cap_quarter_end.csv
# Summary for Passenger Airlines sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.907593e+10    UAL
# 1 2019-12-31 00:00:00-05:00  2.897069e+10    UAL
# 2 2020-03-31 00:00:00-04:00  1.037604e+10    UAL
# 3 2020-06-30 00:00:00-04:00  1.138240e+10    UAL
# 4 2020-09-30 00:00:00-04:00  1.142844e+10    UAL
#
# ==================================================
#
# Processing Electrical Components & Equipment sector (5 companies)...
# ['AME', 'ETN', 'EMR', 'GNRC', 'ROK']
# Results saved to sector_mkt_cap_results/Electrical Components & Equipment_mkt_cap_quarter_end.csv
# Summary for Electrical Components & Equipment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.661018e+09   GNRC
# 1 2019-12-31 00:00:00-05:00  5.984833e+09   GNRC
# 2 2020-03-31 00:00:00-04:00  5.543363e+09   GNRC
# 3 2020-06-30 00:00:00-04:00  7.254506e+09   GNRC
# 4 2020-09-30 00:00:00-04:00  1.152106e+10   GNRC
#
# ==================================================
#
# Processing Health Care Equipment sector (18 companies)...
# ['ABT', 'BAX', 'BDX', 'BSX', 'DXCM', 'EW', 'GEHC', 'HOLX', 'IDXX', 'PODD', 'ISRG', 'MDT', 'RMD', 'RVTY', 'STE', 'SYK', 'TFX', 'ZBH']
# Results saved to sector_mkt_cap_results/Health Care Equipment_mkt_cap_quarter_end.csv
# Summary for Health Care Equipment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.457310e+10   DXCM
# 1 2019-12-31 00:00:00-05:00  2.135969e+10   DXCM
# 2 2020-03-31 00:00:00-04:00  2.629388e+10   DXCM
# 3 2020-06-30 00:00:00-04:00  3.958680e+10   DXCM
# 4 2020-09-30 00:00:00-04:00  4.025375e+10   DXCM
#
# ==================================================
#
# Skipping Commodity Chemicals sector: Only 1 companies found.
# No results to save for Commodity Chemicals sector.
#
# ==================================================
#
# Processing Restaurants sector (6 companies)...
# ['CMG', 'DRI', 'DPZ', 'MCD', 'SBUX', 'YUM']
# Results saved to sector_mkt_cap_results/Restaurants_mkt_cap_quarter_end.csv
# Summary for Restaurants sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  9.017728e+10   SBUX
# 1 2019-12-31 00:00:00-05:00  9.011556e+10   SBUX
# 2 2020-03-31 00:00:00-04:00  6.769572e+10   SBUX
# 3 2020-06-30 00:00:00-04:00  7.620750e+10   SBUX
# 4 2020-09-30 00:00:00-04:00  8.946008e+10   SBUX
#
# ==================================================
#
# Processing Diversified Banks sector (7 companies)...
# ['BAC', 'C', 'JPM', 'PNC', 'TFC', 'USB', 'WFC']
# Results saved to sector_mkt_cap_results/Diversified Banks_mkt_cap_quarter_end.csv
# Summary for Diversified Banks sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.976690e+11    BAC
# 1 2019-12-31 00:00:00-05:00  2.399695e+11    BAC
# 2 2020-03-31 00:00:00-04:00  1.455724e+11    BAC
# 3 2020-06-30 00:00:00-04:00  1.639876e+11    BAC
# 4 2020-09-30 00:00:00-04:00  1.674939e+11    BAC
#
# ==================================================
#
# Processing Internet Services & Infrastructure sector (4 companies)...
# ['AKAM', 'GDDY', 'PLTR', 'VRSN']
# Results saved to sector_mkt_cap_results/Internet Services & Infrastructure_mkt_cap_quarter_end.csv
# Summary for Internet Services & Infrastructure sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.372774e+10   AKAM
# 1 2019-12-31 00:00:00-05:00  1.297661e+10   AKAM
# 2 2020-03-31 00:00:00-04:00  1.374427e+10   AKAM
# 3 2020-06-30 00:00:00-04:00  1.608781e+10   AKAM
# 4 2020-09-30 00:00:00-04:00  1.660609e+10   AKAM
#
# ==================================================
#
# Processing Distributors sector (3 companies)...
# ['GPC', 'LKQ', 'POOL']
# Results saved to sector_mkt_cap_results/Distributors_mkt_cap_quarter_end.csv
# Summary for Distributors sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.592924e+09    LKQ
# 1 2019-12-31 00:00:00-05:00  8.618994e+09    LKQ
# 2 2020-03-31 00:00:00-04:00  4.951696e+09    LKQ
# 3 2020-06-30 00:00:00-04:00  6.325425e+09    LKQ
# 4 2020-09-30 00:00:00-04:00  6.694809e+09    LKQ
#
# ==================================================
#
# Processing Property & Casualty Insurance sector (8 companies)...
# ['ALL', 'ACGL', 'CB', 'CINF', 'HIG', 'PGR', 'TRV', 'WRB']
# Results saved to sector_mkt_cap_results/Property & Casualty Insurance_mkt_cap_quarter_end.csv
# Summary for Property & Casualty Insurance sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.579464e+10   ACGL
# 1 2019-12-31 00:00:00-05:00  1.613702e+10   ACGL
# 2 2020-03-31 00:00:00-04:00  1.070785e+10   ACGL
# 3 2020-06-30 00:00:00-04:00  1.077933e+10   ACGL
# 4 2020-09-30 00:00:00-04:00  1.100508e+10   ACGL
#
# ==================================================
#
# Processing Rail Transportation sector (3 companies)...
# ['CSX', 'NSC', 'UNP']
# Results saved to sector_mkt_cap_results/Rail Transportation_mkt_cap_quarter_end.csv
# Summary for Rail Transportation sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.173963e+10    CSX
# 1 2019-12-31 00:00:00-05:00  4.374748e+10    CSX
# 2 2020-03-31 00:00:00-04:00  3.476251e+10    CSX
# 3 2020-06-30 00:00:00-04:00  4.245955e+10    CSX
# 4 2020-09-30 00:00:00-04:00  4.744946e+10    CSX
#
# ==================================================
#
# Skipping Construction Materials sector: Only 2 companies found.
# No results to save for Construction Materials sector.
#
# ==================================================
#
# Processing Multi-line Insurance sector (3 companies)...
# ['AIG', 'AIZ', 'L']
# Results saved to sector_mkt_cap_results/Multi-line Insurance_mkt_cap_quarter_end.csv
# Summary for Multi-line Insurance sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  5.878171e+09    AIZ
# 1 2019-12-31 00:00:00-05:00  6.153216e+09    AIZ
# 2 2020-03-31 00:00:00-04:00  4.908080e+09    AIZ
# 3 2020-06-30 00:00:00-04:00  4.900905e+09    AIZ
# 4 2020-09-30 00:00:00-04:00  5.785391e+09    AIZ
#
# ==================================================
#
# Skipping Copper sector: Only 1 companies found.
# No results to save for Copper sector.
#
# ==================================================
#
# Processing Packaged Foods & Meats sector (12 companies)...
# ['CPB', 'CAG', 'GIS', 'HSY', 'HRL', 'K', 'KHC', 'LW', 'MKC', 'MDLZ', 'SJM', 'TSN']
# Results saved to sector_mkt_cap_results/Packaged Foods & Meats_mkt_cap_quarter_end.csv
# Summary for Packaged Foods & Meats sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.208048e+10    CAG
# 1 2019-12-31 00:00:00-05:00  1.358640e+10    CAG
# 2 2020-03-31 00:00:00-04:00  1.171725e+10    CAG
# 3 2020-06-30 00:00:00-04:00  1.413251e+10    CAG
# 4 2020-09-30 00:00:00-04:00  1.443157e+10    CAG
#
# ==================================================
#
# Processing Diversified Support Services sector (4 companies)...
# ['AMTM', 'CTAS', 'CPRT', 'LDOS']
# Results saved to sector_mkt_cap_results/Diversified Support Services_mkt_cap_quarter_end.csv
# Summary for Diversified Support Services sector:
#                        Date     MarketCap Ticker
# 0 2024-09-30 00:00:00-04:00  6.245562e+09   AMTM
# 1 2019-09-30 00:00:00-04:00  1.934698e+10   CPRT
# 2 2019-12-31 00:00:00-05:00  2.190233e+10   CPRT
# 3 2020-03-31 00:00:00-04:00  1.650261e+10   CPRT
# 4 2020-06-30 00:00:00-04:00  2.005506e+10   CPRT
#
# ==================================================
#
# Skipping Hotel & Resort REITs sector: Only 2 companies found.
# No results to save for Hotel & Resort REITs sector.
#
# ==================================================
#
# Processing Oil & Gas Exploration & Production sector (9 companies)...
# ['APA', 'COP', 'CTRA', 'DVN', 'FANG', 'EOG', 'EQT', 'MRO', 'OXY']
# Results saved to sector_mkt_cap_results/Oil & Gas Exploration & Production_mkt_cap_quarter_end.csv
# Summary for Oil & Gas Exploration & Production sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.104552e+10   FANG
# 1 2019-12-31 00:00:00-05:00  2.178923e+10   FANG
# 2 2020-03-31 00:00:00-04:00  6.185137e+09   FANG
# 3 2020-06-30 00:00:00-04:00  9.964033e+09   FANG
# 4 2020-09-30 00:00:00-04:00  7.237449e+09   FANG
#
# ==================================================
#
# Skipping Integrated Telecommunication Services sector: Only 2 companies found.
# No results to save for Integrated Telecommunication Services sector.
#
# ==================================================
#
# Skipping Brewers sector: Only 1 companies found.
# No results to save for Brewers sector.
#
# ==================================================
#
# Skipping Leisure Products sector: Only 1 companies found.
# No results to save for Leisure Products sector.
#
# ==================================================
#
# Processing IT Consulting & Other Services sector (5 companies)...
# ['ACN', 'CTSH', 'EPAM', 'IT', 'IBM']
# Results saved to sector_mkt_cap_results/IT Consulting & Other Services_mkt_cap_quarter_end.csv
# Summary for IT Consulting & Other Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.774994e+10   CTSH
# 1 2019-12-31 00:00:00-05:00  2.864608e+10   CTSH
# 2 2020-03-31 00:00:00-04:00  2.153182e+10   CTSH
# 3 2020-06-30 00:00:00-04:00  2.643694e+10   CTSH
# 4 2020-09-30 00:00:00-04:00  3.240599e+10   CTSH
#
# ==================================================
#
# Processing Asset Management & Custody Banks sector (10 companies)...
# ['AMP', 'BLK', 'BX', 'BK', 'BEN', 'IVZ', 'KKR', 'NTRS', 'STT', 'TROW']
# Results saved to sector_mkt_cap_results/Asset Management & Custody Banks_mkt_cap_quarter_end.csv
# Summary for Asset Management & Custody Banks sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.931382e+10     BX
# 1 2019-12-31 00:00:00-05:00  3.388760e+10     BX
# 2 2020-03-31 00:00:00-04:00  2.787039e+10     BX
# 3 2020-06-30 00:00:00-04:00  3.491363e+10     BX
# 4 2020-09-30 00:00:00-04:00  3.238457e+10     BX
#
# ==================================================
#
# Skipping Drug Retail sector: Only 1 companies found.
# No results to save for Drug Retail sector.
#
# ==================================================
#
# Processing Technology Hardware, Storage & Peripherals sector (8 companies)...
# ['AAPL', 'DELL', 'HPE', 'HPQ', 'NTAP', 'STX', 'SMCI', 'WDC']
# Results saved to sector_mkt_cap_results/Technology Hardware, Storage & Peripherals_mkt_cap_quarter_end.csv
# Summary for Technology Hardware, Storage & Peripherals sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  9.239133e+09   NTAP
# 1 2019-12-31 00:00:00-05:00  1.105618e+10   NTAP
# 2 2020-03-31 00:00:00-04:00  7.462068e+09   NTAP
# 3 2020-06-30 00:00:00-04:00  8.038197e+09   NTAP
# 4 2020-09-30 00:00:00-04:00  8.030263e+09   NTAP
#
# ==================================================
#
# Skipping Industrial REITs sector: Only 1 companies found.
# No results to save for Industrial REITs sector.
#
# ==================================================
#
# Skipping Cargo Ground Transportation sector: Only 2 companies found.
# No results to save for Cargo Ground Transportation sector.
#
# ==================================================
#
# Processing Oil & Gas Refining & Marketing sector (3 companies)...
# ['MPC', 'PSX', 'VLO']
# Results saved to sector_mkt_cap_results/Oil & Gas Refining & Marketing_mkt_cap_quarter_end.csv
# Summary for Oil & Gas Refining & Marketing sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  3.429499e+10    PSX
# 1 2019-12-31 00:00:00-05:00  3.759585e+10    PSX
# 2 2020-03-31 00:00:00-04:00  1.828663e+10    PSX
# 3 2020-06-30 00:00:00-04:00  2.481847e+10    PSX
# 4 2020-09-30 00:00:00-04:00  1.815075e+10    PSX
#
# ==================================================
#
# Processing Investment Banking & Brokerage sector (4 companies)...
# ['SCHW', 'GS', 'MS', 'RJF']
# Results saved to sector_mkt_cap_results/Investment Banking & Brokerage_mkt_cap_quarter_end.csv
# Summary for Investment Banking & Brokerage sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  5.751926e+10     GS
# 1 2019-12-31 00:00:00-05:00  6.417976e+10     GS
# 2 2020-03-31 00:00:00-04:00  4.341413e+10     GS
# 3 2020-06-30 00:00:00-04:00  5.584536e+10     GS
# 4 2020-09-30 00:00:00-04:00  5.713586e+10     GS
#
# ==================================================
#
# Skipping Independent Power Producers & Energy Traders sector: Only 2 companies found.
# No results to save for Independent Power Producers & Energy Traders sector.
#
# ==================================================
#
# Skipping Timber REITs sector: Only 1 companies found.
# No results to save for Timber REITs sector.
#
# ==================================================
#
# Processing Electric Utilities sector (15 companies)...
# ['LNT', 'AEP', 'CEG', 'DUK', 'EIX', 'ETR', 'EVRG', 'ES', 'EXC', 'FE', 'PPL', 'PEG', 'SO', 'VST', 'WEC']
# Results saved to sector_mkt_cap_results/Electric Utilities_mkt_cap_quarter_end.csv
# Summary for Electric Utilities sector:
#                        Date     MarketCap Ticker
# 0 2022-03-31 00:00:00-04:00  1.718902e+10    CEG
# 1 2022-06-30 00:00:00-04:00  1.754077e+10    CEG
# 2 2022-09-30 00:00:00-04:00  2.552972e+10    CEG
# 3 2022-12-31 00:00:00-05:00  2.649698e+10    CEG
# 4 2023-03-31 00:00:00-04:00  2.421347e+10    CEG
#
# ==================================================
#
# Skipping Consumer Electronics sector: Only 1 companies found.
# No results to save for Consumer Electronics sector.
#
# ==================================================
#
# Processing Movies & Entertainment sector (4 companies)...
# ['LYV', 'NFLX', 'PARA', 'DIS']
# Results saved to sector_mkt_cap_results/Movies & Entertainment_mkt_cap_quarter_end.csv
# Summary for Movies & Entertainment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.539844e+10    LYV
# 1 2019-12-31 00:00:00-05:00  1.658919e+10    LYV
# 2 2020-03-31 00:00:00-04:00  1.055190e+10    LYV
# 3 2020-06-30 00:00:00-04:00  1.028961e+10    LYV
# 4 2020-09-30 00:00:00-04:00  1.250630e+10    LYV
#
# ==================================================
#
# Processing Oil & Gas Storage & Transportation sector (4 companies)...
# ['KMI', 'OKE', 'TRGP', 'WMB']
# Results saved to sector_mkt_cap_results/Oil & Gas Storage & Transportation_mkt_cap_quarter_end.csv
# Summary for Oil & Gas Storage & Transportation sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.579890e+09   TRGP
# 1 2019-12-31 00:00:00-05:00  7.882737e+09   TRGP
# 2 2020-03-31 00:00:00-04:00  1.366748e+09   TRGP
# 3 2020-06-30 00:00:00-04:00  4.002454e+09   TRGP
# 4 2020-09-30 00:00:00-04:00  2.812631e+09   TRGP
#
# ==================================================
#
# Skipping Construction & Engineering sector: Only 2 companies found.
# No results to save for Construction & Engineering sector.
#
# ==================================================
#
# Skipping Other Specialty Retail sector: Only 2 companies found.
# No results to save for Other Specialty Retail sector.
#
# ==================================================
#
# Processing Aerospace & Defense sector (12 companies)...
# ['AXON', 'BA', 'GE', 'GD', 'HWM', 'HII', 'LHX', 'LMT', 'NOC', 'RTX', 'TXT', 'TDG']
# Results saved to sector_mkt_cap_results/Aerospace & Defense_mkt_cap_quarter_end.csv
# Summary for Aerospace & Defense sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.329747e+09   AXON
# 1 2019-12-31 00:00:00-05:00  5.587952e+09   AXON
# 2 2020-03-31 00:00:00-04:00  5.396552e+09   AXON
# 3 2020-06-30 00:00:00-04:00  7.482883e+09   AXON
# 4 2020-09-30 00:00:00-04:00  6.916310e+09   AXON
#
# ==================================================
#
# Skipping Single-Family Residential REITs sector: Only 1 companies found.
# No results to save for Single-Family Residential REITs sector.
#
# ==================================================
#
# Processing Apparel, Accessories & Luxury Goods sector (4 companies)...
# ['LULU', 'NKE', 'RL', 'TPR']
# Results saved to sector_mkt_cap_results/Apparel, Accessories & Luxury Goods_mkt_cap_quarter_end.csv
# Summary for Apparel, Accessories & Luxury Goods sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.265327e+10   LULU
# 1 2019-12-31 00:00:00-05:00  2.725852e+10   LULU
# 2 2020-03-31 00:00:00-04:00  2.230264e+10   LULU
# 3 2020-06-30 00:00:00-04:00  3.671141e+10   LULU
# 4 2020-09-30 00:00:00-04:00  3.875400e+10   LULU
#
# ==================================================
#
# Skipping Water Utilities sector: Only 1 companies found.
# No results to save for Water Utilities sector.
#
# ==================================================
#
# Skipping Broadline Retail sector: Only 2 companies found.
# No results to save for Broadline Retail sector.
#
# ==================================================
#
# Skipping Agricultural Products & Services sector: Only 2 companies found.
# No results to save for Agricultural Products & Services sector.
#
# ==================================================
#
# Processing Consumer Staples Merchandise Retail sector (5 companies)...
# ['COST', 'DG', 'DLTR', 'TGT', 'WMT']
# Results saved to sector_mkt_cap_results/Consumer Staples Merchandise Retail_mkt_cap_quarter_end.csv
# Summary for Consumer Staples Merchandise Retail sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  3.291629e+10     DG
# 1 2019-12-31 00:00:00-05:00  3.236762e+10     DG
# 2 2020-03-31 00:00:00-04:00  3.140095e+10     DG
# 3 2020-06-30 00:00:00-04:00  3.970269e+10     DG
# 4 2020-09-30 00:00:00-04:00  4.376841e+10     DG
#
# ==================================================
#
# Skipping Food Retail sector: Only 1 companies found.
# No results to save for Food Retail sector.
#
# ==================================================
#
# Skipping Health Care Facilities sector: Only 2 companies found.
# No results to save for Health Care Facilities sector.
#
# ==================================================
#
# Processing Soft Drinks & Non-alcoholic Beverages sector (4 companies)...
# ['KO', 'KDP', 'MNST', 'PEP']
# Results saved to sector_mkt_cap_results/Soft Drinks & Non-alcoholic Beverages_mkt_cap_quarter_end.csv
# Summary for Soft Drinks & Non-alcoholic Beverages sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.823226e+10   MNST
# 1 2019-12-31 00:00:00-05:00  3.090182e+10   MNST
# 2 2020-03-31 00:00:00-04:00  2.735699e+10   MNST
# 3 2020-06-30 00:00:00-04:00  3.370754e+10   MNST
# 4 2020-09-30 00:00:00-04:00  3.899805e+10   MNST
#
# ==================================================
#
# Skipping Tobacco sector: Only 2 companies found.
# No results to save for Tobacco sector.
#
# ==================================================
#
# Skipping Automotive Parts & Equipment sector: Only 2 companies found.
# No results to save for Automotive Parts & Equipment sector.
#
# ==================================================
#
# Skipping Apparel Retail sector: Only 2 companies found.
# No results to save for Apparel Retail sector.
#
# ==================================================
#
# Skipping Gas Utilities sector: Only 1 companies found.
# No results to save for Gas Utilities sector.
#
# ==================================================
#
# Processing Oil & Gas Equipment & Services sector (3 companies)...
# ['BKR', 'HAL', 'SLB']
# Results saved to sector_mkt_cap_results/Oil & Gas Equipment & Services_mkt_cap_quarter_end.csv
# Summary for Oil & Gas Equipment & Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.962120e+10    BKR
# 1 2019-12-31 00:00:00-05:00  2.185558e+10    BKR
# 2 2020-03-31 00:00:00-04:00  9.026406e+09    BKR
# 3 2020-06-30 00:00:00-04:00  1.338640e+10    BKR
# 4 2020-09-30 00:00:00-04:00  1.168521e+10    BKR
#
# ==================================================
#
# Processing Health Care Services sector (5 companies)...
# ['CI', 'CVS', 'DVA', 'LH', 'DGX']
# Results saved to sector_mkt_cap_results/Health Care Services_mkt_cap_quarter_end.csv
# Summary for Health Care Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.681110e+09    DVA
# 1 2019-12-31 00:00:00-05:00  6.154261e+09    DVA
# 2 2020-03-31 00:00:00-04:00  6.238745e+09    DVA
# 3 2020-06-30 00:00:00-04:00  6.491379e+09    DVA
# 4 2020-09-30 00:00:00-04:00  7.025356e+09    DVA
#
# ==================================================
#
# Skipping Interactive Home Entertainment sector: Only 2 companies found.
# No results to save for Interactive Home Entertainment sector.
#
# ==================================================
#
# Skipping Other Specialized REITs sector: Only 1 companies found.
# No results to save for Other Specialized REITs sector.
#
# ==================================================
#
# Skipping Metal, Glass & Plastic Containers sector: Only 1 companies found.
# No results to save for Metal, Glass & Plastic Containers sector.
#
# ==================================================
#
# Processing Broadcasting sector (3 companies)...
# ['FOXA', 'FOX', 'WBD']
# Results saved to sector_mkt_cap_results/Broadcasting_mkt_cap_quarter_end.csv
# Summary for Broadcasting sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  6.888298e+09    FOX
# 1 2019-12-31 00:00:00-05:00  7.949715e+09    FOX
# 2 2020-03-31 00:00:00-04:00  5.033380e+09    FOX
# 3 2020-06-30 00:00:00-04:00  5.904542e+09    FOX
# 4 2020-09-30 00:00:00-04:00  6.204463e+09    FOX
#
# ==================================================
#
# Skipping Advertising sector: Only 2 companies found.
# No results to save for Advertising sector.
#
# ==================================================
#
# Processing Retail REITs sector (5 companies)...
# ['FRT', 'KIM', 'O', 'REG', 'SPG']
# Results saved to sector_mkt_cap_results/Retail REITs_mkt_cap_quarter_end.csv
# Summary for Retail REITs sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.020326e+10    REG
# 1 2019-12-31 00:00:00-05:00  9.346937e+09    REG
# 2 2020-03-31 00:00:00-04:00  5.746875e+09    REG
# 3 2020-06-30 00:00:00-04:00  6.976143e+09    REG
# 4 2020-09-30 00:00:00-04:00  5.859592e+09    REG
#
# ==================================================
#
# Processing Multi-Utilities sector (12 companies)...
# ['AEE', 'CNP', 'CMS', 'ED', 'D', 'DTE', 'NEE', 'NI', 'PCG', 'PNW', 'SRE', 'XEL']
# Results saved to sector_mkt_cap_results/Multi-Utilities_mkt_cap_quarter_end.csv
# Summary for Multi-Utilities sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.635403e+10    CMS
# 1 2019-12-31 00:00:00-05:00  1.616706e+10    CMS
# 2 2020-03-31 00:00:00-04:00  1.520617e+10    CMS
# 3 2020-06-30 00:00:00-04:00  1.523454e+10    CMS
# 4 2020-09-30 00:00:00-04:00  1.611974e+10    CMS
#
# ==================================================
#
# Processing Construction Machinery & Heavy Transportation Equipment sector (4 companies)...
# ['CAT', 'CMI', 'PCAR', 'WAB']
# Results saved to sector_mkt_cap_results/Construction Machinery & Heavy Transportation Equipment_mkt_cap_quarter_end.csv
# Summary for Construction Machinery & Heavy Transportation Equipment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.196111e+10    WAB
# 1 2019-12-31 00:00:00-05:00  1.296967e+10    WAB
# 2 2020-03-31 00:00:00-04:00  8.035429e+09    WAB
# 3 2020-06-30 00:00:00-04:00  9.633269e+09    WAB
# 4 2020-09-30 00:00:00-04:00  1.037227e+10    WAB
#
# ==================================================
#
# Processing Health Care REITs sector (3 companies)...
# ['DOC', 'VTR', 'WELL']
# Results saved to sector_mkt_cap_results/Health Care REITs_mkt_cap_quarter_end.csv
# Summary for Health Care REITs sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.745668e+10   WELL
# 1 2019-12-31 00:00:00-05:00  4.326600e+10   WELL
# 2 2020-03-31 00:00:00-04:00  2.446186e+10   WELL
# 3 2020-06-30 00:00:00-04:00  2.807311e+10   WELL
# 4 2020-09-30 00:00:00-04:00  3.020969e+10   WELL
#
# ==================================================
#
# Processing Life & Health Insurance sector (5 companies)...
# ['AFL', 'GL', 'MET', 'PFG', 'PRU']
# Results saved to sector_mkt_cap_results/Life & Health Insurance_mkt_cap_quarter_end.csv
# Summary for Life & Health Insurance sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.721497e+10    MET
# 1 2019-12-31 00:00:00-05:00  2.969006e+10    MET
# 2 2020-03-31 00:00:00-04:00  1.796607e+10    MET
# 3 2020-06-30 00:00:00-04:00  2.176659e+10    MET
# 4 2020-09-30 00:00:00-04:00  2.242656e+10    MET
#
# ==================================================
#
# Skipping Footwear sector: Only 1 companies found.
# No results to save for Footwear sector.
#
# ==================================================
#
# Processing Industrial Machinery & Supplies & Components sector (14 companies)...
# ['DOV', 'FTV', 'HUBB', 'IEX', 'ITW', 'IR', 'NDSN', 'OTIS', 'PH', 'PNR', 'SNA', 'SWK', 'GWW', 'XYL']
# Results saved to sector_mkt_cap_results/Industrial Machinery & Supplies & Components_mkt_cap_quarter_end.csv
# Summary for Industrial Machinery & Supplies & Components sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  6.384707e+09   HUBB
# 1 2019-12-31 00:00:00-05:00  7.226737e+09   HUBB
# 2 2020-03-31 00:00:00-04:00  5.647197e+09   HUBB
# 3 2020-06-30 00:00:00-04:00  6.215008e+09   HUBB
# 4 2020-09-30 00:00:00-04:00  6.826293e+09   HUBB
#
# ==================================================
#
# Skipping Electronic Components sector: Only 2 companies found.
# No results to save for Electronic Components sector.
#
# ==================================================
#
# Skipping Food Distributors sector: Only 1 companies found.
# No results to save for Food Distributors sector.
#
# ==================================================
#
# Processing Semiconductors sector (15 companies)...
# ['AMD', 'ADI', 'AVGO', 'FSLR', 'INTC', 'MCHP', 'MU', 'MPWR', 'NVDA', 'NXPI', 'ON', 'QRVO', 'QCOM', 'SWKS', 'TXN']
# Results saved to sector_mkt_cap_results/Semiconductors_mkt_cap_quarter_end.csv
# Summary for Semiconductors sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  5.060282e+10    ADI
# 1 2019-12-31 00:00:00-05:00  5.407824e+10    ADI
# 2 2020-03-31 00:00:00-04:00  4.101675e+10    ADI
# 3 2020-06-30 00:00:00-04:00  5.641537e+10    ADI
# 4 2020-09-30 00:00:00-04:00  5.397903e+10    ADI
#
# ==================================================
#
# Processing Household Products sector (4 companies)...
# ['CHD', 'CLX', 'CL', 'KMB']
# Results saved to sector_mkt_cap_results/Household Products_mkt_cap_quarter_end.csv
# Summary for Household Products sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.737518e+10    CHD
# 1 2019-12-31 00:00:00-05:00  1.630029e+10    CHD
# 2 2020-03-31 00:00:00-04:00  1.491799e+10    CHD
# 3 2020-06-30 00:00:00-04:00  1.802650e+10    CHD
# 4 2020-09-30 00:00:00-04:00  2.190880e+10    CHD
#
# ==================================================
#
# Processing Hotels, Resorts & Cruise Lines sector (8 companies)...
# ['ABNB', 'BKNG', 'CCL', 'EXPE', 'HLT', 'MAR', 'NCLH', 'RCL']
# Results saved to sector_mkt_cap_results/Hotels, Resorts & Cruise Lines_mkt_cap_quarter_end.csv
# Summary for Hotels, Resorts & Cruise Lines sector:
#                        Date     MarketCap Ticker
# 0 2020-12-31 00:00:00-05:00  6.354634e+10   ABNB
# 1 2021-03-31 00:00:00-04:00  8.135490e+10   ABNB
# 2 2021-06-30 00:00:00-04:00  6.629078e+10   ABNB
# 3 2021-09-30 00:00:00-04:00  7.261512e+10   ABNB
# 4 2021-12-31 00:00:00-05:00  7.206969e+10   ABNB
#
# ==================================================
#
# Skipping Home Furnishings sector: Only 1 companies found.
# No results to save for Home Furnishings sector.
#
# ==================================================
#
# Skipping Passenger Ground Transportation sector: Only 1 companies found.
# No results to save for Passenger Ground Transportation sector.
#
# ==================================================
#
# Skipping Agricultural & Farm Machinery sector: Only 1 companies found.
# No results to save for Agricultural & Farm Machinery sector.
#
# ==================================================
#
# Skipping Multi-Sector Holdings sector: Only 1 companies found.
# No results to save for Multi-Sector Holdings sector.
#
# ==================================================
#
# Skipping Home Improvement Retail sector: Only 2 companies found.
# No results to save for Home Improvement Retail sector.
#
# ==================================================
#
# Skipping Data Processing & Outsourced Services sector: Only 1 companies found.
# No results to save for Data Processing & Outsourced Services sector.
#
# ==================================================
#
# Processing Fertilizers & Agricultural Chemicals sector (4 companies)...
# ['CF', 'CTVA', 'FMC', 'MOS']
# Results saved to sector_mkt_cap_results/Fertilizers & Agricultural Chemicals_mkt_cap_quarter_end.csv
# Summary for Fertilizers & Agricultural Chemicals sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  6.027381e+09    MOS
# 1 2019-12-31 00:00:00-05:00  6.379871e+09    MOS
# 2 2020-03-31 00:00:00-04:00  3.199340e+09    MOS
# 3 2020-06-30 00:00:00-04:00  3.713742e+09    MOS
# 4 2020-09-30 00:00:00-04:00  5.438208e+09    MOS
#
# ==================================================
#
# Processing Managed Health Care sector (5 companies)...
# ['CNC', 'ELV', 'HUM', 'MOH', 'UNH']
# Results saved to sector_mkt_cap_results/Managed Health Care_mkt_cap_quarter_end.csv
# Summary for Managed Health Care sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  6.275984e+09    MOH
# 1 2019-12-31 00:00:00-05:00  7.761468e+09    MOH
# 2 2020-03-31 00:00:00-04:00  7.991412e+09    MOH
# 3 2020-06-30 00:00:00-04:00  1.018046e+10    MOH
# 4 2020-09-30 00:00:00-04:00  1.046989e+10    MOH
#
# ==================================================
#
# Processing Financial Exchanges & Data sector (9 companies)...
# ['CBOE', 'CME', 'FDS', 'ICE', 'MKTX', 'MCO', 'MSCI', 'NDAQ', 'SPGI']
# Results saved to sector_mkt_cap_results/Financial Exchanges & Data_mkt_cap_quarter_end.csv
# Summary for Financial Exchanges & Data sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  4.961502e+10    ICE
# 1 2019-12-31 00:00:00-05:00  4.991688e+10    ICE
# 2 2020-03-31 00:00:00-04:00  4.371031e+10    ICE
# 3 2020-06-30 00:00:00-04:00  4.974348e+10    ICE
# 4 2020-09-30 00:00:00-04:00  5.449500e+10    ICE
#
# ==================================================
#
# Skipping Research & Consulting Services sector: Only 2 companies found.
# No results to save for Research & Consulting Services sector.
#
# ==================================================
#
# Skipping Steel sector: Only 2 companies found.
# No results to save for Steel sector.
#
# ==================================================
#
# Processing Interactive Media & Services sector (4 companies)...
# ['GOOGL', 'GOOG', 'MTCH', 'META']
# Results saved to sector_mkt_cap_results/Interactive Media & Services_mkt_cap_quarter_end.csv
# Summary for Interactive Media & Services sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.842402e+10   MTCH
# 1 2019-12-31 00:00:00-05:00  2.117576e+10   MTCH
# 2 2020-03-31 00:00:00-04:00  1.703139e+10   MTCH
# 3 2020-06-30 00:00:00-04:00  2.760766e+10   MTCH
# 4 2020-09-30 00:00:00-04:00  2.853608e+10   MTCH
#
# ==================================================
#
# Skipping Distillers & Vintners sector: Only 2 companies found.
# No results to save for Distillers & Vintners sector.
#
# ==================================================
#
# Skipping Publishing sector: Only 2 companies found.
# No results to save for Publishing sector.
#
# ==================================================
#
# Processing Consumer Finance sector (4 companies)...
# ['AXP', 'COF', 'DFS', 'SYF']
# Results saved to sector_mkt_cap_results/Consumer Finance_mkt_cap_quarter_end.csv
# Summary for Consumer Finance sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.807349e+10    DFS
# 1 2019-12-31 00:00:00-05:00  1.900449e+10    DFS
# 2 2020-03-31 00:00:00-04:00  8.039048e+09    DFS
# 3 2020-06-30 00:00:00-04:00  1.141528e+10    DFS
# 4 2020-09-30 00:00:00-04:00  1.328253e+10    DFS
#
# ==================================================
#
# Processing Specialty Chemicals sector (9 companies)...
# ['ALB', 'CE', 'DD', 'EMN', 'ECL', 'IFF', 'LYB', 'PPG', 'SHW']
# Results saved to sector_mkt_cap_results/Specialty Chemicals_mkt_cap_quarter_end.csv
# Summary for Specialty Chemicals sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.190529e+10     CE
# 1 2019-12-31 00:00:00-05:00  1.204656e+10     CE
# 2 2020-03-31 00:00:00-04:00  7.221294e+09     CE
# 3 2020-06-30 00:00:00-04:00  8.563573e+09     CE
# 4 2020-09-30 00:00:00-04:00  1.072800e+10     CE
#
# ==================================================
#
# Processing Telecom Tower REITs sector (3 companies)...
# ['AMT', 'CCI', 'SBAC']
# Results saved to sector_mkt_cap_results/Telecom Tower REITs_mkt_cap_quarter_end.csv
# Summary for Telecom Tower REITs sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.447844e+10   SBAC
# 1 2019-12-31 00:00:00-05:00  2.449998e+10   SBAC
# 2 2020-03-31 00:00:00-04:00  2.749096e+10   SBAC
# 3 2020-06-30 00:00:00-04:00  3.038524e+10   SBAC
# 4 2020-09-30 00:00:00-04:00  3.253170e+10   SBAC
#
# ==================================================
#
# Processing Application Software sector (11 companies)...
# ['ADBE', 'ANSS', 'ADSK', 'CDNS', 'FICO', 'INTU', 'ORCL', 'PTC', 'CRM', 'SNPS', 'TYL']
# Results saved to sector_mkt_cap_results/Application Software_mkt_cap_quarter_end.csv
# Summary for Application Software sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.812330e+10   CDNS
# 1 2019-12-31 00:00:00-05:00  1.902288e+10   CDNS
# 2 2020-03-31 00:00:00-04:00  1.811233e+10   CDNS
# 3 2020-06-30 00:00:00-04:00  2.631828e+10   CDNS
# 4 2020-09-30 00:00:00-04:00  2.924466e+10   CDNS
#
# ==================================================
#
# Processing Pharmaceuticals sector (8 companies)...
# ['BMY', 'CTLT', 'JNJ', 'LLY', 'MRK', 'PFE', 'VTRS', 'ZTS']
# Results saved to sector_mkt_cap_results/Pharmaceuticals_mkt_cap_quarter_end.csv
# Summary for Pharmaceuticals sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  8.650862e+09   CTLT
# 1 2019-12-31 00:00:00-05:00  1.021913e+10   CTLT
# 2 2020-03-31 00:00:00-04:00  9.429549e+09   CTLT
# 3 2020-06-30 00:00:00-04:00  1.330483e+10   CTLT
# 4 2020-09-30 00:00:00-04:00  1.554832e+10   CTLT
#
# ==================================================
#
# Skipping Reinsurance sector: Only 1 companies found.
# No results to save for Reinsurance sector.
#
# ==================================================
#
# Skipping Trading Companies & Distributors sector: Only 2 companies found.
# No results to save for Trading Companies & Distributors sector.
#
# ==================================================
#
# Processing Regional Banks sector (6 companies)...
# ['CFG', 'FITB', 'HBAN', 'KEY', 'MTB', 'RF']
# Results saved to sector_mkt_cap_results/Regional Banks_mkt_cap_quarter_end.csv
# Summary for Regional Banks sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.383830e+10    KEY
# 1 2019-12-31 00:00:00-05:00  1.585119e+10    KEY
# 2 2020-03-31 00:00:00-04:00  8.214329e+09    KEY
# 3 2020-06-30 00:00:00-04:00  9.801088e+09    KEY
# 4 2020-09-30 00:00:00-04:00  9.741037e+09    KEY
#
# ==================================================
#
# Processing Automotive Retail sector (3 companies)...
# ['AZO', 'KMX', 'ORLY']
# Results saved to sector_mkt_cap_results/Automotive Retail_mkt_cap_quarter_end.csv
# Summary for Automotive Retail sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  2.300626e+10   ORLY
# 1 2019-12-31 00:00:00-05:00  2.530106e+10   ORLY
# 2 2020-03-31 00:00:00-04:00  1.737983e+10   ORLY
# 3 2020-06-30 00:00:00-04:00  2.434331e+10   ORLY
# 4 2020-09-30 00:00:00-04:00  2.661847e+10   ORLY
#
# ==================================================
#
# Processing Communications Equipment sector (5 companies)...
# ['ANET', 'CSCO', 'FFIV', 'JNPR', 'MSI']
# Results saved to sector_mkt_cap_results/Communications Equipment_mkt_cap_quarter_end.csv
# Summary for Communications Equipment sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.078696e+09   JNPR
# 1 2019-12-31 00:00:00-05:00  7.097739e+09   JNPR
# 2 2020-03-31 00:00:00-04:00  5.566874e+09   JNPR
# 3 2020-06-30 00:00:00-04:00  6.705376e+09   JNPR
# 4 2020-09-30 00:00:00-04:00  6.359317e+09   JNPR
#
# ==================================================
#
# Processing Air Freight & Logistics sector (4 companies)...
# ['CHRW', 'EXPD', 'FDX', 'UPS']
# Results saved to sector_mkt_cap_results/Air Freight & Logistics_mkt_cap_quarter_end.csv
# Summary for Air Freight & Logistics sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  7.406528e+10    UPS
# 1 2019-12-31 00:00:00-05:00  7.292343e+10    UPS
# 2 2020-03-31 00:00:00-04:00  5.877336e+10    UPS
# 3 2020-06-30 00:00:00-04:00  7.068033e+10    UPS
# 4 2020-09-30 00:00:00-04:00  1.066063e+11    UPS
#
# ==================================================
#
# Processing Homebuilding sector (4 companies)...
# ['DHI', 'LEN', 'NVR', 'PHM']
# Results saved to sector_mkt_cap_results/Homebuilding_mkt_cap_quarter_end.csv
# Summary for Homebuilding sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.249094e+10    LEN
# 1 2019-12-31 00:00:00-05:00  1.248569e+10    LEN
# 2 2020-03-31 00:00:00-04:00  8.565360e+09    LEN
# 3 2020-06-30 00:00:00-04:00  1.385704e+10    LEN
# 4 2020-09-30 00:00:00-04:00  1.840320e+10    LEN
#
# ==================================================
#
# Skipping Computer & Electronics Retail sector: Only 1 companies found.
# No results to save for Computer & Electronics Retail sector.
#
# ==================================================
#
# Processing Biotechnology sector (8 companies)...
# ['ABBV', 'AMGN', 'BIIB', 'GILD', 'INCY', 'MRNA', 'REGN', 'VRTX']
# Results saved to sector_mkt_cap_results/Biotechnology_mkt_cap_quarter_end.csv
# Summary for Biotechnology sector:
#                        Date     MarketCap Ticker
# 0 2019-09-30 00:00:00-04:00  1.430041e+10   INCY
# 1 2019-12-31 00:00:00-05:00  1.682220e+10   INCY
# 2 2020-03-31 00:00:00-04:00  1.410776e+10   INCY
# 3 2020-06-30 00:00:00-04:00  2.002982e+10   INCY
# 4 2020-09-30 00:00:00-04:00  1.728841e+10   INCY
#
# ==================================================
#
# All sectors processed.

# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import yfinance as yf
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

WIKI_URL = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

def scrape_wikipedia_sp500():
    """Scrape S&P 500 companies and their sectors from Wikipedia."""
    response = requests.get(WIKI_URL)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    table = soup.find('table', {'id': 'constituents'})
    rows = table.find_all('tr')[1:]  # Skip header row
    
    companies_data = []
    for row in rows:
        cols = row.find_all('td')
        ticker = cols[0].text.strip()
        company_name = cols[1].text.strip()
        sector = cols[3].text.strip()
        companies_data.append((ticker, company_name, sector))
    
    return companies_data

def get_sector_companies(sector, companies_data):
    """Return the list of companies belonging to a sector."""
    return [company[0] for company in companies_data if company[2] == sector]

def download_market_cap_data(ticker, start_date, end_date):
    """Download the stock's market capitalization at the quarter end."""
    try:
        stock = yf.Ticker(ticker)
        df = stock.history(start=start_date, end=end_date)
        if df.empty:
            return None

        # Calculate Market Cap = Close Price * Shares Outstanding
        shares_outstanding = stock.info.get('sharesOutstanding', None)
        if shares_outstanding is None:
            return None
        
        df['MarketCap'] = df['Close'] * shares_outstanding
        df = df[['MarketCap']]  # Only keep MarketCap column
        
        # Resample to get the last value at the end of each quarter
        df = df.resample('QE').last()
        df['Ticker'] = ticker  # Add ticker as a column
        return df
    except Exception as e:
        return None

def calculate_returns(data):
    """Calculate quarterly returns based on market cap."""
    data['Return'] = data['MarketCap'].pct_change()
    return data.dropna(subset=['Return'])

def calculate_beta(sector_returns, market_returns):
    """Calculate beta using aligned sector and market returns."""
    # Align the series to have matching dates
    aligned_returns = sector_returns.align(market_returns, join='inner')
    aligned_sector_returns = aligned_returns[0]
    aligned_market_returns = aligned_returns[1]
    
    # Calculate covariance and beta
    covariance = np.cov(aligned_sector_returns, aligned_market_returns)[0, 1]
    market_variance = np.var(aligned_market_returns)
    beta = covariance / market_variance
    return beta


def process_sector_with_beta(sector, start_date, end_date, companies_data, market_returns):
    """Calculate quarterly returns and beta for a sector."""
    companies = get_sector_companies(sector, companies_data)
    results = []

    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_ticker = {executor.submit(download_market_cap_data, ticker, start_date, end_date): ticker for ticker in companies}
        for future in as_completed(future_to_ticker):
            result = future.result()
            if result is not None:
                results.append(result)

    if not results:
        return None

    # Combine the results into a single DataFrame
    combined_results = pd.concat(results)
    combined_results.reset_index(inplace=True)
    
    # Calculate sector returns
    sector_returns = combined_results.groupby('Date')['MarketCap'].sum()
    sector_returns = calculate_returns(sector_returns.to_frame())

    # Calculate beta
    beta_value = calculate_beta(sector_returns['Return'], market_returns)
    return beta_value

def main():
    start_date = pd.Timestamp('2019-09-30')
    end_date = pd.Timestamp('2024-09-30')
    
    # Scrape Wikipedia for S&P 500 companies and sectors
    companies_data = scrape_wikipedia_sp500()
    
    # Get unique sectors
    sectors = list(set(company[2] for company in companies_data))
    
    # Load market index data for beta calculation (assuming S&P 500)
    market_data = yf.Ticker('^GSPC').history(start=start_date, end=end_date)
    market_data = market_data.resample('QE').last()  # Quarterly end
    market_data['Return'] = market_data['Close'].pct_change().dropna()
    market_returns = market_data['Return']
    
    # Calculate and store sector betas
    sector_betas = {}
    for sector in sectors:
        beta_value = process_sector_with_beta(sector, start_date, end_date, companies_data, market_returns)
        if beta_value is not None:
            sector_betas[sector] = beta_value
    
    # Save to CSV
    beta_df = pd.DataFrame(sector_betas.items(), columns=['Sector', 'Beta'])
    beta_df.to_csv('sector_beta_values.csv', index=False)
    print("Sector beta values saved to sector_beta_values.csv")

if __name__ == "__main__":
    main()
# Out:
# /var/folders/v6/xy5gt_l13w19zhqpg7vkhmvh0000gn/T/ipykernel_21096/3785646590.py:69: RuntimeWarning: Degrees of freedom <= 0 for slice
#   covariance = np.cov(aligned_sector_returns, aligned_market_returns)[0, 1]
# /Users/tanishkyadav/Documents/IDP/.venv/lib/python3.9/site-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/tanishkyadav/Documents/IDP/.venv/lib/python3.9/site-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /var/folders/v6/xy5gt_l13w19zhqpg7vkhmvh0000gn/T/ipykernel_21096/3785646590.py:69: RuntimeWarning: Degrees of freedom <= 0 for slice
#   covariance = np.cov(aligned_sector_returns, aligned_market_returns)[0, 1]
# /Users/tanishkyadav/Documents/IDP/.venv/lib/python3.9/site-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/tanishkyadav/Documents/IDP/.venv/lib/python3.9/site-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# $BRK.B: possibly delisted; no timezone found
# $BF.B: possibly delisted; no price data found  (1d 2019-09-30 00:00:00 -> 2024-09-30 00:00:00)
# $PTC: possibly delisted; no price data found  (1d 2019-09-30 00:00:00 -> 2024-09-30 00:00:00)
# Sector beta values saved to sector_beta_values.csv

# %%
def classify_growth(value):
    """Classify YoY growth into 1, 0, or -1 based on thresholds."""
    if value > 5:
        return 1
    elif value < -5:
        return -1
    else:
        return 0

def calculate_yoy_growth(df, column):
    """Calculate YoY growth and classify based on threshold."""
    df[f'{column}_YoY_Growth'] = df[column].pct_change(periods=4) * 100  # YoY percentage change
    df[f'{column}_Growth_Class'] = df[f'{column}_YoY_Growth'].apply(classify_growth)
    df.dropna(subset=[f'{column}_YoY_Growth'], inplace=True)
    return df

def calculate_beta_growth_covariance(df, period):
    """Calculate the covariance of beta growth over a specified period."""
    df[f'Beta_Growth_{period}_M'] = df['Beta'].pct_change(periods=period)
    beta_covariance = df[f'Beta_Growth_{period}_M'].cov(df['Beta'])
    return beta_covariance

def calculate_sector_index_variations(df, sorted_companies, total_overperformance):
    """Calculate sector index and return variations between weighted and simple average index."""
    fractional_contribution = {company: count**2 / total_overperformance for company, count in sorted_companies}

    sector_index = pd.DataFrame()

    for ticker in df['Ticker'].unique():
        company_data = df[df['Ticker'] == ticker].copy()

        if ticker in fractional_contribution:
            contribution = fractional_contribution[ticker]
            company_data['Weighted_YoY_Growth'] = company_data['MarketCap_Growth_Class'] * contribution
        else:
            continue

        if sector_index.empty:
            sector_index = company_data[['Date', 'Weighted_YoY_Growth']].copy()
        else:
            sector_index = pd.merge(sector_index, company_data[['Date', 'Weighted_YoY_Growth']],
                                    on='Date', how='outer', suffixes=('', f'_{ticker}'))

    sector_index['Weighted_Index'] = sector_index.filter(like='Weighted_YoY_Growth').sum(axis=1)

    # Calculate simple average
    simple_avg_index = df.groupby('Date')['MarketCap_Growth_Class'].mean().reset_index()
    sector_index = pd.merge(sector_index, simple_avg_index, on='Date', how='left')
    sector_index.rename(columns={'MarketCap_Growth_Class': 'Simple_Avg_Index'}, inplace=True)

    # Calculate the difference between the weighted and simple averages
    sector_index['Difference'] = (sector_index['Weighted_Index'] - sector_index['Simple_Avg_Index']).abs()

    return sector_index[['Date', 'Weighted_Index', 'Simple_Avg_Index', 'Difference']]

def calculate_variance_and_covariances(df):
    """Calculate variance of YoY growth and the covariances of beta growth."""
    # Variance of YoY growth in market cap
    variance = df['MarketCap_Growth_Class'].var()

    # Covariance for 6 months and 5 years of beta growth
    beta_cov_6m = calculate_beta_growth_covariance(df, period=6)
    beta_cov_5y = calculate_beta_growth_covariance(df, period=20)  # Assuming 5 years corresponds to approx. 20 quarters

    return variance, beta_cov_6m, beta_cov_5y

def get_sector_rankings(input_dir, output_file='sector_rankings.csv'):
    rankings_variation = {}
    rankings_variance = {}
    rankings_cov_6m_beta = {}
    rankings_cov_5y_beta = {}

    for sector_file in os.listdir(input_dir):
        if sector_file.endswith(".csv"):
            sector = sector_file.replace("_mkt_cap_quarter_end.csv", "")
            print(f"Processing {sector} sector...")

            # Load the CSV file and filter data for 2019-2024
            file_path = os.path.join(input_dir, sector_file)
            df = pd.read_csv(file_path, parse_dates=['Date'])

            # Convert 'Date' to UTC
            df['Date'] = pd.to_datetime(df['Date'], utc=True)

            # Filter the data from 2019 onwards
            df = df[df['Date'] >= pd.Timestamp('2019-01-01', tz='UTC')]

            # Calculate YoY growth for MarketCap and Revenue
            df = calculate_yoy_growth(df, 'MarketCap')
            df = calculate_yoy_growth(df, 'Revenue')

            # Calculate sector leader and fractional contributions
            sector_leader, sorted_companies, total_overperformance = calculate_sector_leader_and_rank(df, sector)

            # Calculate sector index variations
            sector_index_variations = calculate_sector_index_variations(df, sorted_companies, total_overperformance)

            # Calculate variance of YoY growth and beta covariances
            variance, beta_cov_6m, beta_cov_5y = calculate_variance_and_covariances(df)

            # Summarize the variation between weighted and simple averages
            avg_difference = sector_index_variations['Difference'].mean()

            # Save results for rankings
            rankings_variation[sector] = avg_difference
            rankings_variance[sector] = variance
            rankings_cov_6m_beta[sector] = beta_cov_6m
            rankings_cov_5y_beta[sector] = beta_cov_5y

    # Create a DataFrame from the rankings
    rankings_df = pd.DataFrame({
        'Sector': list(rankings_variation.keys()),
        'Variation (Weighted vs Simple Avg)': list(rankings_variation.values()),
        'Variance of YoY Growth': list(rankings_variance.values()),
        'Covariance of 6M Beta Growth': list(rankings_cov_6m_beta.values()),
        'Covariance of 5Y Beta Growth': list(rankings_cov_5y_beta.values())
    })

    # Save the rankings DataFrame to CSV
    rankings_df.to_csv(output_file, index=False)
    print(f"\nRankings saved to {output_file}")

    # Optionally, print the rankings (as before)
    print("\nRanking of sectors based on variation between simple and weighted averages:")
    for sector, value in sorted(rankings_variation.items(), key=lambda x: x[1], reverse=True):
        print(f"{sector}: {value}")

    print("\nRanking of sectors based on variance of YoY growth over time:")
    for sector, value in sorted(rankings_variance.items(), key=lambda x: x[1], reverse=True):
        print(f"{sector}: {value}")

    print("\nRanking of sectors based on covariance of 6M Beta Growth:")
    for sector, value in sorted(rankings_cov_6m_beta.items(), key=lambda x: x[1], reverse=True):
        print(f"{sector}: {value}")

    print("\nRanking of sectors based on covariance of 5Y Beta Growth:")
    for sector, value in sorted(rankings_cov_5y_beta.items(), key=lambda x: x[1], reverse=True):
        print(f"{sector}: {value}")

def main():
    input_dir = "merged_sector_data"
    get_sector_rankings(input_dir)

if __name__ == "__main__":
    main()
# Out:
# Processing Internet Services & Infrastructure_merged_data.csv sector...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 177
#     174     get_sector_rankings(input_dir)
#     176 if __name__ == "__main__":
# --> 177     main()
#
# Cell In[12], line 174, in main()
#     172 def main():
#     173     input_dir = "merged_sector_data"
# --> 174     get_sector_rankings(input_dir)
#
# Cell In[12], line 125, in get_sector_rankings(input_dir, output_file)
#     122 df = calculate_yoy_growth(df, 'Revenue')
#     124 # Calculate sector leader and fractional contributions
# --> 125 sector_leader, sorted_companies, total_overperformance = calculate_sector_leader_and_rank(df, sector)
#     127 # Calculate sector index variations
#     128 sector_index_variations = calculate_sector_index_variations(df, sorted_companies, total_overperformance)
#
# Cell In[12], line 13, in calculate_sector_leader_and_rank(df, sector)
#      11 """Calculate the leader and performance ranking for a sector."""
#      12 # Calculate the average YoY growth of the sector per quarter
# ---> 13 sector_avg = df.groupby('Date')['YoY_Growth'].mean()
#      15 # Count how many times each company outperforms the sector average
#      16 overperformance_counts = {}
#
# File ~/Documents/IDP/.venv/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~/Documents/IDP/.venv/lib/python3.9/site-packages/pandas/core/base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: YoY_Growth'
